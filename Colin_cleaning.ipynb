# %%
#import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import os
from scipy.stats import linregress
import numpy as np

# %%
#import the dataset
file_path = os.path.join("Resources", "life_expectancy_data_region.csv")

cleaning_df = pd.read_csv(file_path)
cleaning_df.head()
# Out:
#        Country  Year                 Region      Status  Life expectancy   \
# 0  Afghanistan  2015  Eastern Mediterranean  Developing              65.0
# 1  Afghanistan  2014  Eastern Mediterranean  Developing              59.9
# 2  Afghanistan  2013  Eastern Mediterranean  Developing              59.9
# 3  Afghanistan  2012  Eastern Mediterranean  Developing              59.5
# 4  Afghanistan  2011  Eastern Mediterranean  Developing              59.2
#
#    Adult Mortality  infant deaths  Alcohol  percentage expenditure  \
# 0            263.0             62     0.01               71.279624
# 1            271.0             64     0.01               73.523582
# 2            268.0             66     0.01               73.219243
# 3            272.0             69     0.01               78.184215
# 4            275.0             71     0.01                7.097109
#
#    Hepatitis B  ...  Polio  Total expenditure  Diphtheria    HIV/AIDS  \
# ...

# %%
cleaning_df.count()
# Out:
# Country                            2938
# Year                               2938
# Region                             2938
# Status                             2938
# Life expectancy                    2928
# Adult Mortality                    2928
# infant deaths                      2938
# Alcohol                            2744
# percentage expenditure             2938
# Hepatitis B                        2385
# Measles                            2938
#  BMI                               2904
# under-five deaths                  2938
# Polio                              2919
# Total expenditure                  2712
# Diphtheria                         2919
#  HIV/AIDS                          2938
# GDP                                2490
# Population                         2286
#  thinness  1-19 years              2904
#  thinness 5-9 years                2904
# Income composition of resources    2771
# Schooling                          2775
# dtype: int64

# %%
cleaning_df.dropna()
cleaning_df['Alcohol'].dtypes
# Out:
# dtype('float64')

# %%
valuecount = cleaning_df["Population"].value_counts()
valuecount = pd.DataFrame(valuecount)

# %%
valuecount.index.to_list()
# Out:
# [73.0,
#  75.0,
#  78.0,
#  73.6,
#  76.0,
#  73.9,
#  81.0,
#  74.7,
#  74.5,
#  74.2,
#  74.4,
#  73.2,
#  74.1,
#  73.5,
#  74.9,
#  73.8,
#  77.0,
#  72.0,
#  82.0,
#  74.0,
#  73.3,
#  72.7,
#  75.4,
#  74.6,
#  68.0,
#  72.6,
#  72.9,
#  72.8,
#  79.0,
#  73.4,
#  73.7,
#  71.0,
#  73.1,
#  74.8,
#  72.5,
#  81.1,
#  83.0,
#  71.7,
#  72.2,
#  75.6,
#  75.3,
#  71.4,
#  78.7,
#  69.4,
#  75.2,
#  71.8,
#  86.0,
#  72.4,
#  72.3,
#  69.0,
#  71.6,
#  75.8,
#  71.9,
#  74.3,
#  55.0,
#  72.1,
#  71.2,
#  79.3,
#  65.0,
#  75.5,
#  67.0,
#  62.0,
#  58.0,
#  78.9,
#  76.2,
#  68.5,
#  85.0,
#  78.1,
#  79.4,
#  63.0,
#  89.0,
#  80.0,
#  69.9,
#  76.6,
#  67.5,
#  79.7,
#  64.0,
#  84.0,
#  68.3,
#  66.0,
#  78.8,
#  81.7,
#  55.3,
#  76.1,
#  59.7,
#  79.8,
#  67.3,
#  77.5,
#  67.7,
#  71.1,
#  79.1,
#  79.5,
#  66.6,
#  81.5,
#  68.4,
#  67.6,
#  88.0,
#  67.8,
#  68.7,
#  76.9,
#  76.3,
#  77.3,
#  78.3,
#  59.3,
#  69.6,
#  75.7,
#  77.8,
#  69.1,
#  79.9,
#  75.1,
#  65.8,
# ...
